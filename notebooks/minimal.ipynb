# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# модель из последовательности слоевa
model = Sequential()

# добавляем слои
model.add(Dense(units=1, activation='linear'))
#model.add(Dense(units=64, activation='relu'))
#model.add(Dense(units=10, activation='softmax'))

# настройки обучения
model.compile(loss='mse',
              optimizer='sgd')

# пример расширения настройки (через наследование)
# model.compile(
#     loss=keras.losses.categorical_crossentropy,
#     optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
# )

# %%
print(model)

# %%
# данные
x_train = np.array([0.3, 0.7, 1.5])
y_train = np.array([1.5, 3.5, 7.5])

# обучение
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1513
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1439
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1367
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1296
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1225
# Epoch 6/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1156
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.1088
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1020
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0953
# Epoch 10/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0887
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0822
# Epoch 12/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.0758
# ...

# %%
x_test = np.array([3, 15])
y_test = np.array([15, 75])

# проверка качества обучения
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
print(loss_and_metrics)

# ИЛИ генерация прогноза на новых данных
classes = model.predict(x_test, batch_size=128)
print(classes)
# Out:
# 1/1 [==============================] - 0s 14ms/step - loss: 247.1470
# 247.14703369140625
# [[11.809084]
#  [52.99745 ]]
